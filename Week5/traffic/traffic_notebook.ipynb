# %%
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)
# Out:
# /content/drive
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/
# Out:
# /content/drive

# %%
# !git clone https://github.com/briancy02/cs50-briancy02.git
# Out:
# Cloning into 'cs50-briancy02'...
# remote: Enumerating objects: 26876, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 26876 (delta 57), reused 167 (delta 56), pack-reused 26708
# Receiving objects: 100% (26876/26876), 197.46 MiB | 9.83 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# Checking out files: 100% (99/99), done.

# %%
# !git config --global user.name "Brian Yoon"
# !git config --global user.email "byoon2002@gmail.com"

# %%
# %cd cs50-briancy02/Week5/traffic/
# !git remote set-url origin https://briancy02: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@github.com/briancy02/cs50-briancy02.git
# !git add .
# !git commit -am "test"
# !git push
# Out:
# /content/drive/My Drive/cs50-briancy02/Week5/traffic
# [main a17141cf] test
#  2 files changed, 1 insertion(+)
#  create mode 100644 Week5/traffic/Untitled1.ipynb
#  create mode 100644 Week5/traffic/te.txt
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git push
# Out:
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (6/6), 1.49 KiB | 304.00 KiB/s, done.
# Total 6 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/briancy02/cs50-briancy02.git
#    94fabcc6..a17141cf  main -> main
