# %% [markdown]
# ### **Setup script**

# %%
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)
# Out:
# /content/drive
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/

# %%
# !git clone https://github.com/briancy02/cs50-briancy02.git

# %%
# %cd cs50-briancy02/Week5/traffic/
# !git config --global user.name "Brian Yoon"
# !git config --global user.email "byoon2002@gmail.com"
# !git remote set-url origin https://briancy02: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@github.com/briancy02/cs50-briancy02.git

# !git commit -am "changed notebook"
# !git push
# Out:
# [Errno 2] No such file or directory: 'cs50-briancy02/Week5/traffic/'
# /content/drive/MyDrive/cs50-briancy02/Week5/traffic
# [main 4a8a3579] changed notebook
#  1 file changed, 1 insertion(+), 1 deletion(-)
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://briancy02: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@github.com/briancy02/cs50-briancy02.git/'

# %%
# !git remote remove origin
# !git remote add origin https://briancy02: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@github.com/briancy02/cs50-briancy02.git

# %%
# !git push --set-upstream origin main
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://briancy02: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@github.com/briancy02/cs50-briancy02.git/'

# %%
# %cd drive/MyDrive/cs50-briancy02/Week5/traffic/

# %% [markdown]
# ### **ML Code**

# %%
# !python3 traffic.py

# %%
# !unzip traffic.p
