# %% [markdown]
# ### **Setup script**

# %%
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)
# Out:
# /content/drive
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fexperimentsandconfigs%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
#
# Enter your authorization code:
# 4/1AX4XfWhWunLbyas0HFbolw-3OygQljRYHddaUfLxz4bNqRjguuaxw6H_Yh4

# %%
# %cd drive/MyDrive/

# %%
# !git clone https://github.com/briancy02/cs50-briancy02.git

# %%
# %cd cs50-briancy02/Week5/traffic/
# !git config --global user.name "Brian Yoon"
# !git config --global user.email "byoon2002@gmail.com"

# %%
# %cd drive/MyDrive/cs50-briancy02/Week5/traffic/
# !git commit -am "changed notebook"
# Out:
# /content
# [Errno 2] No such file or directory: 'content/drive/MyDrive/cs50-briancy02/Week5/traffic/'
# /content
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# ### **ML Code**

# %%
# !python3 traffic.py
# Out:
# 2021-08-15 13:58:54.180682: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Usage: python traffic.py data_directory [model.h5]

# %%
# !unzip traffic.p
# Out:
# /content/drive/My Drive/cs50-briancy02/Week5/traffic
